# %%
import requests
import pandas as pd
import time

# Step 1: Load the dataset from the URL
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
data = pd.read_csv(url, sep=',', header=0, names=columns)

# Step 2: Prepare the input data for the model (exclude the 'species' column for prediction)
features = data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# Step 3: Define the API endpoint
api_url = "http://localhost:8000/predict"  # Change this to your deployed model's URL

# Step 4: Send data in batches to the API and get predictions
# Since this is just an example, we'll process one sample at a time here.

predictions = []
start_time = time.time()
print(f"Sending {len(features)} samples to the model...")
for i, row in features.iterrows():
    sample = row.to_dict()  # Convert row to a dictionary
    print(f"Sending sample {i}: {sample}")
    response = requests.post(api_url, json=[sample])  # Send the request

    if response.status_code == 200:
        prediction = response.json()['predictions'][0]  # Extract prediction
        predictions.append(prediction)
        print(f"Prediction: {prediction}, Actual: {data['species'][i]}")
    else:
        print(f"Error: {response.status_code}, {response.text}")
        predictions.append(None)

# Step 5: Calculate the latency (Time taken to process all requests)
latency = time.time() - start_time
print(f"Latency: {latency:.4f} seconds for {len(features)} samples.")

# Step 6: Evaluate accuracy (if you have the ground truth 'species')
# For the sake of this example, we are assuming the model is a classification model.
# You would compare the model's predictions with the actual 'species' values.

actual_labels = data['species']
accuracy = sum([1 if pred == actual else 0 for pred, actual in zip(predictions, actual_labels)]) / len(actual_labels)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Sending 150 samples to the model...
# Sending sample 0: {'sepal_length': 5.1, 'sepal_width': 3.5, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 1: {'sepal_length': 4.9, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 2: {'sepal_length': 4.7, 'sepal_width': 3.2, 'petal_length': 1.3, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 3: {'sepal_length': 4.6, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 4: {'sepal_length': 5.0, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 5: {'sepal_length': 5.4, 'sepal_width': 3.9, 'petal_length': 1.7, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 6: {'sepal_length': 4.6, 'sepal_width': 3.4, 'petal_length': 1.4, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 7: {'sepal_length': 5.0, 'sepal_width': 3.4, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 8: {'sepal_length': 4.4, 'sepal_width': 2.9, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 9: {'sepal_length': 4.9, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.1}
# Prediction: setosa, Actual: setosa
# Sending sample 10: {'sepal_length': 5.4, 'sepal_width': 3.7, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 11: {'sepal_length': 4.8, 'sepal_width': 3.4, 'petal_length': 1.6, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 12: {'sepal_length': 4.8, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.1}
# Prediction: setosa, Actual: setosa
# Sending sample 13: {'sepal_length': 4.3, 'sepal_width': 3.0, 'petal_length': 1.1, 'petal_width': 0.1}
# Prediction: setosa, Actual: setosa
# Sending sample 14: {'sepal_length': 5.8, 'sepal_width': 4.0, 'petal_length': 1.2, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 15: {'sepal_length': 5.7, 'sepal_width': 4.4, 'petal_length': 1.5, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 16: {'sepal_length': 5.4, 'sepal_width': 3.9, 'petal_length': 1.3, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 17: {'sepal_length': 5.1, 'sepal_width': 3.5, 'petal_length': 1.4, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 18: {'sepal_length': 5.7, 'sepal_width': 3.8, 'petal_length': 1.7, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 19: {'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.5, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 20: {'sepal_length': 5.4, 'sepal_width': 3.4, 'petal_length': 1.7, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 21: {'sepal_length': 5.1, 'sepal_width': 3.7, 'petal_length': 1.5, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 22: {'sepal_length': 4.6, 'sepal_width': 3.6, 'petal_length': 1.0, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 23: {'sepal_length': 5.1, 'sepal_width': 3.3, 'petal_length': 1.7, 'petal_width': 0.5}
# Prediction: setosa, Actual: setosa
# Sending sample 24: {'sepal_length': 4.8, 'sepal_width': 3.4, 'petal_length': 1.9, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 25: {'sepal_length': 5.0, 'sepal_width': 3.0, 'petal_length': 1.6, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 26: {'sepal_length': 5.0, 'sepal_width': 3.4, 'petal_length': 1.6, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 27: {'sepal_length': 5.2, 'sepal_width': 3.5, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 28: {'sepal_length': 5.2, 'sepal_width': 3.4, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 29: {'sepal_length': 4.7, 'sepal_width': 3.2, 'petal_length': 1.6, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 30: {'sepal_length': 4.8, 'sepal_width': 3.1, 'petal_length': 1.6, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 31: {'sepal_length': 5.4, 'sepal_width': 3.4, 'petal_length': 1.5, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 32: {'sepal_length': 5.2, 'sepal_width': 4.1, 'petal_length': 1.5, 'petal_width': 0.1}
# Prediction: setosa, Actual: setosa
# Sending sample 33: {'sepal_length': 5.5, 'sepal_width': 4.2, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 34: {'sepal_length': 4.9, 'sepal_width': 3.1, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 35: {'sepal_length': 5.0, 'sepal_width': 3.2, 'petal_length': 1.2, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 36: {'sepal_length': 5.5, 'sepal_width': 3.5, 'petal_length': 1.3, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 37: {'sepal_length': 4.9, 'sepal_width': 3.6, 'petal_length': 1.4, 'petal_width': 0.1}
# Prediction: setosa, Actual: setosa
# Sending sample 38: {'sepal_length': 4.4, 'sepal_width': 3.0, 'petal_length': 1.3, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 39: {'sepal_length': 5.1, 'sepal_width': 3.4, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 40: {'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.3, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 41: {'sepal_length': 4.5, 'sepal_width': 2.3, 'petal_length': 1.3, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 42: {'sepal_length': 4.4, 'sepal_width': 3.2, 'petal_length': 1.3, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 43: {'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.6, 'petal_width': 0.6}
# Prediction: setosa, Actual: setosa
# Sending sample 44: {'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.9, 'petal_width': 0.4}
# Prediction: setosa, Actual: setosa
# Sending sample 45: {'sepal_length': 4.8, 'sepal_width': 3.0, 'petal_length': 1.4, 'petal_width': 0.3}
# Prediction: setosa, Actual: setosa
# Sending sample 46: {'sepal_length': 5.1, 'sepal_width': 3.8, 'petal_length': 1.6, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 47: {'sepal_length': 4.6, 'sepal_width': 3.2, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 48: {'sepal_length': 5.3, 'sepal_width': 3.7, 'petal_length': 1.5, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 49: {'sepal_length': 5.0, 'sepal_width': 3.3, 'petal_length': 1.4, 'petal_width': 0.2}
# Prediction: setosa, Actual: setosa
# Sending sample 50: {'sepal_length': 7.0, 'sepal_width': 3.2, 'petal_length': 4.7, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 51: {'sepal_length': 6.4, 'sepal_width': 3.2, 'petal_length': 4.5, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 52: {'sepal_length': 6.9, 'sepal_width': 3.1, 'petal_length': 4.9, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 53: {'sepal_length': 5.5, 'sepal_width': 2.3, 'petal_length': 4.0, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 54: {'sepal_length': 6.5, 'sepal_width': 2.8, 'petal_length': 4.6, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 55: {'sepal_length': 5.7, 'sepal_width': 2.8, 'petal_length': 4.5, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 56: {'sepal_length': 6.3, 'sepal_width': 3.3, 'petal_length': 4.7, 'petal_width': 1.6}
# Prediction: versicolor, Actual: versicolor
# Sending sample 57: {'sepal_length': 4.9, 'sepal_width': 2.4, 'petal_length': 3.3, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 58: {'sepal_length': 6.6, 'sepal_width': 2.9, 'petal_length': 4.6, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 59: {'sepal_length': 5.2, 'sepal_width': 2.7, 'petal_length': 3.9, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 60: {'sepal_length': 5.0, 'sepal_width': 2.0, 'petal_length': 3.5, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 61: {'sepal_length': 5.9, 'sepal_width': 3.0, 'petal_length': 4.2, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 62: {'sepal_length': 6.0, 'sepal_width': 2.2, 'petal_length': 4.0, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 63: {'sepal_length': 6.1, 'sepal_width': 2.9, 'petal_length': 4.7, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 64: {'sepal_length': 5.6, 'sepal_width': 2.9, 'petal_length': 3.6, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 65: {'sepal_length': 6.7, 'sepal_width': 3.1, 'petal_length': 4.4, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 66: {'sepal_length': 5.6, 'sepal_width': 3.0, 'petal_length': 4.5, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 67: {'sepal_length': 5.8, 'sepal_width': 2.7, 'petal_length': 4.1, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 68: {'sepal_length': 6.2, 'sepal_width': 2.2, 'petal_length': 4.5, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 69: {'sepal_length': 5.6, 'sepal_width': 2.5, 'petal_length': 3.9, 'petal_width': 1.1}
# Prediction: versicolor, Actual: versicolor
# Sending sample 70: {'sepal_length': 5.9, 'sepal_width': 3.2, 'petal_length': 4.8, 'petal_width': 1.8}
# Prediction: virginica, Actual: versicolor
# Sending sample 71: {'sepal_length': 6.1, 'sepal_width': 2.8, 'petal_length': 4.0, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 72: {'sepal_length': 6.3, 'sepal_width': 2.5, 'petal_length': 4.9, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 73: {'sepal_length': 6.1, 'sepal_width': 2.8, 'petal_length': 4.7, 'petal_width': 1.2}
# Prediction: versicolor, Actual: versicolor
# Sending sample 74: {'sepal_length': 6.4, 'sepal_width': 2.9, 'petal_length': 4.3, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 75: {'sepal_length': 6.6, 'sepal_width': 3.0, 'petal_length': 4.4, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 76: {'sepal_length': 6.8, 'sepal_width': 2.8, 'petal_length': 4.8, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 77: {'sepal_length': 6.7, 'sepal_width': 3.0, 'petal_length': 5.0, 'petal_width': 1.7}
# Prediction: versicolor, Actual: versicolor
# Sending sample 78: {'sepal_length': 6.0, 'sepal_width': 2.9, 'petal_length': 4.5, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 79: {'sepal_length': 5.7, 'sepal_width': 2.6, 'petal_length': 3.5, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 80: {'sepal_length': 5.5, 'sepal_width': 2.4, 'petal_length': 3.8, 'petal_width': 1.1}
# Prediction: versicolor, Actual: versicolor
# Sending sample 81: {'sepal_length': 5.5, 'sepal_width': 2.4, 'petal_length': 3.7, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 82: {'sepal_length': 5.8, 'sepal_width': 2.7, 'petal_length': 3.9, 'petal_width': 1.2}
# Prediction: versicolor, Actual: versicolor
# Sending sample 83: {'sepal_length': 6.0, 'sepal_width': 2.7, 'petal_length': 5.1, 'petal_width': 1.6}
# Prediction: virginica, Actual: versicolor
# Sending sample 84: {'sepal_length': 5.4, 'sepal_width': 3.0, 'petal_length': 4.5, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 85: {'sepal_length': 6.0, 'sepal_width': 3.4, 'petal_length': 4.5, 'petal_width': 1.6}
# Prediction: versicolor, Actual: versicolor
# Sending sample 86: {'sepal_length': 6.7, 'sepal_width': 3.1, 'petal_length': 4.7, 'petal_width': 1.5}
# Prediction: versicolor, Actual: versicolor
# Sending sample 87: {'sepal_length': 6.3, 'sepal_width': 2.3, 'petal_length': 4.4, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 88: {'sepal_length': 5.6, 'sepal_width': 3.0, 'petal_length': 4.1, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 89: {'sepal_length': 5.5, 'sepal_width': 2.5, 'petal_length': 4.0, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 90: {'sepal_length': 5.5, 'sepal_width': 2.6, 'petal_length': 4.4, 'petal_width': 1.2}
# Prediction: versicolor, Actual: versicolor
# Sending sample 91: {'sepal_length': 6.1, 'sepal_width': 3.0, 'petal_length': 4.6, 'petal_width': 1.4}
# Prediction: versicolor, Actual: versicolor
# Sending sample 92: {'sepal_length': 5.8, 'sepal_width': 2.6, 'petal_length': 4.0, 'petal_width': 1.2}
# Prediction: versicolor, Actual: versicolor
# Sending sample 93: {'sepal_length': 5.0, 'sepal_width': 2.3, 'petal_length': 3.3, 'petal_width': 1.0}
# Prediction: versicolor, Actual: versicolor
# Sending sample 94: {'sepal_length': 5.6, 'sepal_width': 2.7, 'petal_length': 4.2, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 95: {'sepal_length': 5.7, 'sepal_width': 3.0, 'petal_length': 4.2, 'petal_width': 1.2}
# Prediction: versicolor, Actual: versicolor
# Sending sample 96: {'sepal_length': 5.7, 'sepal_width': 2.9, 'petal_length': 4.2, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 97: {'sepal_length': 6.2, 'sepal_width': 2.9, 'petal_length': 4.3, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 98: {'sepal_length': 5.1, 'sepal_width': 2.5, 'petal_length': 3.0, 'petal_width': 1.1}
# Prediction: versicolor, Actual: versicolor
# Sending sample 99: {'sepal_length': 5.7, 'sepal_width': 2.8, 'petal_length': 4.1, 'petal_width': 1.3}
# Prediction: versicolor, Actual: versicolor
# Sending sample 100: {'sepal_length': 6.3, 'sepal_width': 3.3, 'petal_length': 6.0, 'petal_width': 2.5}
# Prediction: virginica, Actual: virginica
# Sending sample 101: {'sepal_length': 5.8, 'sepal_width': 2.7, 'petal_length': 5.1, 'petal_width': 1.9}
# Prediction: virginica, Actual: virginica
# Sending sample 102: {'sepal_length': 7.1, 'sepal_width': 3.0, 'petal_length': 5.9, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 103: {'sepal_length': 6.3, 'sepal_width': 2.9, 'petal_length': 5.6, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 104: {'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.8, 'petal_width': 2.2}
# Prediction: virginica, Actual: virginica
# Sending sample 105: {'sepal_length': 7.6, 'sepal_width': 3.0, 'petal_length': 6.6, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 106: {'sepal_length': 4.9, 'sepal_width': 2.5, 'petal_length': 4.5, 'petal_width': 1.7}
# Prediction: versicolor, Actual: virginica
# Sending sample 107: {'sepal_length': 7.3, 'sepal_width': 2.9, 'petal_length': 6.3, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 108: {'sepal_length': 6.7, 'sepal_width': 2.5, 'petal_length': 5.8, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 109: {'sepal_length': 7.2, 'sepal_width': 3.6, 'petal_length': 6.1, 'petal_width': 2.5}
# Prediction: virginica, Actual: virginica
# Sending sample 110: {'sepal_length': 6.5, 'sepal_width': 3.2, 'petal_length': 5.1, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 111: {'sepal_length': 6.4, 'sepal_width': 2.7, 'petal_length': 5.3, 'petal_width': 1.9}
# Prediction: virginica, Actual: virginica
# Sending sample 112: {'sepal_length': 6.8, 'sepal_width': 3.0, 'petal_length': 5.5, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 113: {'sepal_length': 5.7, 'sepal_width': 2.5, 'petal_length': 5.0, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 114: {'sepal_length': 5.8, 'sepal_width': 2.8, 'petal_length': 5.1, 'petal_width': 2.4}
# Prediction: virginica, Actual: virginica
# Sending sample 115: {'sepal_length': 6.4, 'sepal_width': 3.2, 'petal_length': 5.3, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 116: {'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.5, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 117: {'sepal_length': 7.7, 'sepal_width': 3.8, 'petal_length': 6.7, 'petal_width': 2.2}
# Prediction: virginica, Actual: virginica
# Sending sample 118: {'sepal_length': 7.7, 'sepal_width': 2.6, 'petal_length': 6.9, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 119: {'sepal_length': 6.0, 'sepal_width': 2.2, 'petal_length': 5.0, 'petal_width': 1.5}
# Prediction: versicolor, Actual: virginica
# Sending sample 120: {'sepal_length': 6.9, 'sepal_width': 3.2, 'petal_length': 5.7, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 121: {'sepal_length': 5.6, 'sepal_width': 2.8, 'petal_length': 4.9, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 122: {'sepal_length': 7.7, 'sepal_width': 2.8, 'petal_length': 6.7, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 123: {'sepal_length': 6.3, 'sepal_width': 2.7, 'petal_length': 4.9, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 124: {'sepal_length': 6.7, 'sepal_width': 3.3, 'petal_length': 5.7, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 125: {'sepal_length': 7.2, 'sepal_width': 3.2, 'petal_length': 6.0, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 126: {'sepal_length': 6.2, 'sepal_width': 2.8, 'petal_length': 4.8, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 127: {'sepal_length': 6.1, 'sepal_width': 3.0, 'petal_length': 4.9, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 128: {'sepal_length': 6.4, 'sepal_width': 2.8, 'petal_length': 5.6, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 129: {'sepal_length': 7.2, 'sepal_width': 3.0, 'petal_length': 5.8, 'petal_width': 1.6}
# Prediction: virginica, Actual: virginica
# Sending sample 130: {'sepal_length': 7.4, 'sepal_width': 2.8, 'petal_length': 6.1, 'petal_width': 1.9}
# Prediction: virginica, Actual: virginica
# Sending sample 131: {'sepal_length': 7.9, 'sepal_width': 3.8, 'petal_length': 6.4, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 132: {'sepal_length': 6.4, 'sepal_width': 2.8, 'petal_length': 5.6, 'petal_width': 2.2}
# Prediction: virginica, Actual: virginica
# Sending sample 133: {'sepal_length': 6.3, 'sepal_width': 2.8, 'petal_length': 5.1, 'petal_width': 1.5}
# Prediction: virginica, Actual: virginica
# Sending sample 134: {'sepal_length': 6.1, 'sepal_width': 2.6, 'petal_length': 5.6, 'petal_width': 1.4}
# Prediction: virginica, Actual: virginica
# Sending sample 135: {'sepal_length': 7.7, 'sepal_width': 3.0, 'petal_length': 6.1, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 136: {'sepal_length': 6.3, 'sepal_width': 3.4, 'petal_length': 5.6, 'petal_width': 2.4}
# Prediction: virginica, Actual: virginica
# Sending sample 137: {'sepal_length': 6.4, 'sepal_width': 3.1, 'petal_length': 5.5, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 138: {'sepal_length': 6.0, 'sepal_width': 3.0, 'petal_length': 4.8, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Sending sample 139: {'sepal_length': 6.9, 'sepal_width': 3.1, 'petal_length': 5.4, 'petal_width': 2.1}
# Prediction: virginica, Actual: virginica
# Sending sample 140: {'sepal_length': 6.7, 'sepal_width': 3.1, 'petal_length': 5.6, 'petal_width': 2.4}
# Prediction: virginica, Actual: virginica
# Sending sample 141: {'sepal_length': 6.9, 'sepal_width': 3.1, 'petal_length': 5.1, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 142: {'sepal_length': 5.8, 'sepal_width': 2.7, 'petal_length': 5.1, 'petal_width': 1.9}
# Prediction: virginica, Actual: virginica
# Sending sample 143: {'sepal_length': 6.8, 'sepal_width': 3.2, 'petal_length': 5.9, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 144: {'sepal_length': 6.7, 'sepal_width': 3.3, 'petal_length': 5.7, 'petal_width': 2.5}
# Prediction: virginica, Actual: virginica
# Sending sample 145: {'sepal_length': 6.7, 'sepal_width': 3.0, 'petal_length': 5.2, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 146: {'sepal_length': 6.3, 'sepal_width': 2.5, 'petal_length': 5.0, 'petal_width': 1.9}
# Prediction: virginica, Actual: virginica
# Sending sample 147: {'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.2, 'petal_width': 2.0}
# Prediction: virginica, Actual: virginica
# Sending sample 148: {'sepal_length': 6.2, 'sepal_width': 3.4, 'petal_length': 5.4, 'petal_width': 2.3}
# Prediction: virginica, Actual: virginica
# Sending sample 149: {'sepal_length': 5.9, 'sepal_width': 3.0, 'petal_length': 5.1, 'petal_width': 1.8}
# Prediction: virginica, Actual: virginica
# Latency: 308.6794 seconds for 150 samples.
# Accuracy: 97.33%
